# %% [markdown]
# <a href="https://colab.research.google.com/github/skyflown/2024-1-my-BDA/blob/main/03w_0325_mon_ch05_dataframe_medium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns

print(sys.version)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.5.3
# 1.25.2

# %%
# !pip install koreanize-matplotlib
# Out:
# Requirement already satisfied: koreanize-matplotlib in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize-matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)

# %%
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# | 함수     | 기능            |
# |----------|-----------------|
# |head()    | 앞부분 출력     |
# |tail()    | 뒷부분 출력     |
# |shape     | 행, 열 개수 출력|
# |info()    | 변수 속성 출력  |
# |describe()| 요약 통계량 출력|

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.

# %%
import pandas as pd
exam = pd.read_csv('exam.csv')

# %%
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.head(10)
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25
# 8   9       3    20       98       15
# 9  10       3    50       98       45

# %%
exam.tail()
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.tail(10)
# Out:
#     id  nclass  math  english  science
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.shape
# Out:
# (20, 5)

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
exam.describe()
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %%
exam.describe(include="all")
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %% [markdown]
# # mpg 데이터 파악하기

# %%
import pandas as pd
mpg = pd.read_csv('data/mpg.csv')

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.describe(include = 'all')
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# unique        10    3         NaN         NaN    5        7
# top     auto(l4)    f         NaN         NaN    r      suv
# freq          83  106         NaN         NaN  168       62
# mean         NaN  NaN   16.858974   23.440171  NaN      NaN
# std          NaN  NaN    4.255946    5.954643  NaN      NaN
# min          NaN  NaN    9.000000   12.000000  NaN      NaN
# 25%          NaN  NaN   14.000000   18.000000  NaN      NaN
# 50%          NaN  NaN   17.000000   24.000000  NaN      NaN
# 75%          NaN  NaN   19.000000   27.000000  NaN      NaN
# max          NaN  NaN   35.000000   44.000000  NaN      NaN

# %%
mpg[["category"]]
# Out:
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 1 columns]

# %%
mpg[["category"]].describe() #범주형 데이터는 깔끔하게 나온다. NaN 없이
# Out:
#        category
# count       234
# unique        7
# top         suv
# freq         62

# %%
mpg[["manufacturer", "model", "trans", "drv", "fl", "category"]].describe()
# Out:
#        manufacturer        model     trans  drv   fl category
# count           234          234       234  234  234      234
# unique           15           38        10    3    5        7
# top           dodge  caravan 2wd  auto(l4)    f    r      suv
# freq             37           11        83  106  168       62

# %% [markdown]
# # 범주형 데이터
#
#
# *   명목형
# *   순서형

# %%
mpg.fl.unique()
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg["fl"].unique()
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg.fl.value_counts()
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_index()
# Out:
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_index(ascending=False)
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_values()
# Out:
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_values(ascending=False)
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg[["fl", "category"]].value_counts()
# Out:
# fl  category
# r   suv           48
#     pickup        30
#     subcompact    29
#     midsize       26
#     compact       25
# p   compact       21
#     midsize       15
# r   minivan       10
# p   suv            8
#     2seater        5
# e   suv            4
# p   subcompact     3
# e   pickup         3
# d   suv            2
#     subcompact     2
#     compact        1
# e   minivan        1
# c   subcompact     1
# dtype: int64

# %%
mpg[["fl", "category"]].value_counts().to_frame()
# Out:
#                 0
# fl category
# r  suv         48
#    pickup      30
#    subcompact  29
#    midsize     26
#    compact     25
# p  compact     21
#    midsize     15
# r  minivan     10
# p  suv          8
#    2seater      5
# e  suv          4
# p  subcompact   3
# e  pickup       3
# d  suv          2
#    subcompact   2
#    compact      1
# e  minivan      1
# c  subcompact   1

# %% [markdown]
# ---

# %% [markdown]
# ### 05-2 변수명 바꾸기(p113): 시험예상

# %%
df_raw = pd.DataFrame({'var1' : [1, 2, 1],
                       'var2' : [2, 3, 2],
                       'var3' : [10, 20, 30]})
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new = df_raw
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(columns = {'var2': 'v2'})
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(columns = {'var2': 'v2'}, inplace=True)
df_new
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_raw
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_new = df_raw.copy()
df_new
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_new.rename(index = {0: "x", 1: "y", 2: "z"}, inplace=True)
df_new
# Out:
#    var1  v2  var3
# x     1   2    10
# y     2   3    20
# z     1   2    30

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
df.rename(columns={"A": "a", "B": "c"})
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# # 05-3 파생변수 만들기: 시험예상

# %%
df = pd.DataFrame({'var1' : [4, 3, 8],
                   'var2' : [2, 6, 1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1 = df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1["var_sum"] = df1["var1"] + df1["var2"]
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
# 새로운 열 var_mean <- var1과 var2의 평균
df1["var_mean"] = (df1["var1"] + df1["var2"]) / 2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2 = df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2.sum() #axis=0 세로(열) 합
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=1) #axis=1 가로(행) 합
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df2["my_sum"] = df2.sum(axis=1) # 새로운 열 추가
df2
# Out:
#    var1  var2  my_sum
# 0     4     2       6
# 1     3     6       9
# 2     8     1       9

# %%
df2["my_sum"] = df2.sum(axis='columns') # sum값 누적되는 것 같다(아님) 전체 값 더해서 sum 값이 나오므로 증가.
df2
# Out:
#    var1  var2  my_sum
# 0     4     2      12
# 1     3     6      18
# 2     8     1      18

# %%
# 새로운 열 var_mean <- var1과 var2의 평균
df2["my_mean"] = df2[["var1","var2"]].mean(axis=1) # 시험 예상
df2
# Out:
#    var1  var2  my_sum  my_mean
# 0     4     2      12      3.0
# 1     3     6      18      4.5
# 2     8     1      18      4.5

# %% [markdown]
# # mpg 통합 연비 변수 만들기

# %%
mpg = pd.read_csv('data/mpg.csv')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# 통합 연비 변수(total) 만들기, total <= cty + hwy의 평균: 시험 예상
mpg['total'] = (mpg['cty'] + mpg['hwy']) / 2  # 통합 연비 변수 만들기
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
# 통합 연비 변수(mpg_mean) 만들기, total <= cty + hwy의 평균: 시험 예상
mpg['mpg_mean'] = mpg[['cty', 'hwy']].mean(axis='columns')  # 통합 연비 변수 만들기
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean
# 0   23.5      23.5
# 1   25.0      25.0
# 2   25.5      25.5
# 3   25.5      25.5
# 4   21.0      21.0

# %%
sum(mpg['total']) / len(mpg)  # total 합계를 행 수로 나누기
# Out:
# 20.14957264957265

# %%
mpg['total'].mean()  # 통합 연비 변수 평균
# Out:
# 20.14957264957265

# %% [markdown]
# ### 조건문을 활용해 파생변수 만들기 (p118)

# %%
mpg['total'].describe()  # 기술(기초, 요약) 통계량 출력
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
# 히스토그램, 도수분포표 만들기
mpg['total'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
mpg['total'].plot(kind="hist", title="히스토그램")
# Out:
# <Axes: title={'center': '히스토그램'}, ylabel='Frequency'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 55176 (\N{HANGUL SYLLABLE HI}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47016 (\N{HANGUL SYLLABLE RAEM}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 55176 (\N{HANGUL SYLLABLE HI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47016 (\N{HANGUL SYLLABLE RAEM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns

sns.histplot(mpg, x="total"); # x=mpg.total  mpg 칸: 어떠한 데이터를 사용하는지 나타낸 칸

# %% [markdown]
# ### 2. 합격 판정 변수 만들기 p120

# %%
import numpy as np

# 20 이상이면 pass, 그렇지 않으면 fail 부여
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')
mpg.sample(10)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 232   volkswagen               passat    2.8  1999    6  manual(m5)   f   18
# 191       toyota         camry solara    3.0  1999    6  manual(m5)   f   18
# 36     chevrolet               malibu    3.6  2008    6    auto(s6)   f   17
# 99         honda                civic    1.6  1999    4  manual(m5)   f   28
# 180       toyota                camry    2.2  1999    4    auto(l4)   f   21
# 233   volkswagen               passat    3.6  2008    6    auto(s6)   f   17
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4   14
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 77          ford         explorer 4wd    4.0  1999    6    auto(l5)   4   14
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4   13
#
#      hwy fl    category  total  mpg_mean  test
# 232   26  p     midsize   22.0      22.0  pass
# 191   26  r     compact   22.0      22.0  pass
# 36    26  r     midsize   21.5      21.5  pass
# 99    33  r  subcompact   30.5      30.5  pass
# 180   27  r     midsize   24.0      24.0  pass
# 233   26  p     midsize   21.5      21.5  pass
# 127   19  r         suv   16.5      16.5  fail
# 69    12  e      pickup   10.5      10.5  fail
# 77    17  r         suv   15.5      15.5  fail
# 66    17  r      pickup   15.0      15.0  fail

# %%
mpg['test'].value_counts()  # 연비 합격 빈도표 만들기
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %%
mpg['test'].unique()
# Out:
# array(['pass', 'fail'], dtype=object)

# %%
count_test = mpg['test'].value_counts()  # 연비 합격 빈도표를 변수에 할당

# %%
type(count_test)
# Out:
# pandas.core.series.Series

# %%
count_test.plot.bar(); # 연비 합격 빈도 막대 그래프 만들기

# %%
count_test.plot.bar(rot = 0);  # 축 이름 수평으로 만들기

# %%
sns.countplot(mpg, x="test", hue=mpg.test); # hue를 쓰지 않아도 되고 (색깔 변환이 필요없다면,), hue="test"와 같다

# %%
sns.countplot(mpg, x='test', hue="cyl", stat= "percent"); #시험 예상  합치면 위의 그래프와 일치, 다 합쳐야 100%이다

# %%
sns.countplot(mpg, x='test', hue="category", stat= "percent"); #시험 예상

# %% [markdown]
# ### 중첩 조건문 활용하기

# %%
# total 기준으로 A, B, C 등급 부여
mpg['grade'] = np.where(mpg['total'] >= 30, 'A',
               np.where(mpg['total'] >= 20, 'B', 'C'))

# 데이터 확인
mpg.sample(5)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 4           audi                   a4    2.8  1999    6    auto(l5)   f   16
# 209   volkswagen                  gti    2.0  2008    4  manual(m6)   f   21
# 65         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 204       toyota    toyota tacoma 4wd    3.4  1999    6    auto(l4)   4   15
# 121      hyundai              tiburon    2.7  2008    6  manual(m5)   f   17
#
#      hwy fl    category  total  mpg_mean  test grade
# 4     26  p     compact   21.0      21.0  pass     B
# 209   29  p     compact   25.0      25.0  pass     B
# 65    12  e      pickup   10.5      10.5  fail     C
# 204   19  r      pickup   17.0      17.0  fail     C
# 121   24  r  subcompact   20.5      20.5  pass     B

# %%
count_grade = mpg['grade'].value_counts()  # 등급 빈도표 만들기
count_grade #value_counts 정렬 기준: 큰 것부터
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
count_grade.plot.bar(rot = 0)  # 등급 빈도 막대 그래프 만들기  위에 나온 가장 큰 순서대로.
# Out:
# <Axes: >

# %%
sns.countplot(mpg, x="grade", hue="grade");

# %%
sns.countplot(mpg, x="grade", hue="grade", stat='percent');

# %%
mpg['grade'].value_counts().sort_index().index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
mpg['grade'].value_counts().sort_index()
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
sns.countplot(mpg, x="grade", hue="grade", order=mpg['grade'].value_counts().sort_index().index);

# %%
count_grade.plot.bar(rot = 0)
# Out:
# <Axes: >

# %%
mpg['grade'].unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
sns.countplot(mpg, x="grade", hue="grade", order=np.sort(mpg['grade'].unique()));

# %% [markdown]
# # (알아 두면 좋아요) 메서드 체이닝 p126

# %%
#메소드 체이닝: 메소드를 계속 연결 --.--.--.--

# %%
# 출력 결과를 변수에 할당하는 방법
s = mpg['grade']
s = s.value_counts()
s = s.sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
s = mpg['grade'].value_counts().sort_index()
s
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
mpg['grade'].value_counts().sort_values()
# Out:
# A     10
# C    106
# B    118
# Name: grade, dtype: int64

# %%
mpg['grade'].value_counts().sort_values(ascending=False)
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %% [markdown]
# # 필요한 만큼 범주 만들기

# %%
# A, B, C, D 등급 변수 만들기
mpg['grade2'] = np.where(mpg['total'] >= 30, 'A',
                np.where(mpg['total'] >= 25, 'B',
                np.where(mpg['total'] >= 20, 'C', 'D')))
mpg.sample(7)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 129         jeep  grand cherokee 4wd    6.1  2008    8    auto(l5)   4   11
# 18     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 161       subaru        forester awd    2.5  2008    4  manual(m5)   4   20
# 131   land rover         range rover    4.2  2008    8    auto(s6)   4   12
# 155      pontiac          grand prix    3.8  1999    6    auto(l4)   f   16
# 98          ford             mustang    5.4  2008    8  manual(m6)   r   14
# 10          audi          a4 quattro    2.0  2008    4    auto(s6)   4   19
#
#      hwy fl    category  total  mpg_mean  test grade grade2
# 129   14  p         suv   12.5      12.5  fail     C      D
# 18    20  r         suv   17.0      17.0  fail     C      D
# 161   27  r         suv   23.5      23.5  pass     B      C
# 131   18  r         suv   15.0      15.0  fail     C      D
# 155   26  p     midsize   21.0      21.0  pass     B      C
# 98    20  p  subcompact   17.0      17.0  fail     C      D
# 10    27  p     compact   23.0      23.0  pass     B      C

# %% [markdown]
# ### 연산자 |(or) 메소드 isin

# %%
mpg['size'] = np.where((mpg['category'] == 'compact') | (mpg['category'] == 'subcompact') | (mpg['category'] == '2seater'),
                       'small', 'large')

mpg['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %%
mpg['size'] = np.where(mpg['category'].isin(['compact', 'subcompact', '2seater']), 'small', 'large') # 시험 문제

mpg['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %% [markdown]
# # 정리하기

# %%
# 1. 패키지 로드
import pandas as pd
import numpy as np

# 2. 데이터 불러오기
mpg = pd.read_csv('data/mpg.csv')

# 3. 데이터 파악하기
mpg.shape       # 행, 열 수
mpg.head()      # 데이터 앞부분
mpg.tail()      # 데이터 뒷부분
mpg.info()      # 속성
mpg.describe()  # 요약 통계량

# 4. 변수명 바꾸기
mpg = mpg.rename(columns = {'manufacturer' : 'company'})

# 5. 파생변수 만들기
mpg['total'] = (mpg['cty'] + mpg['hwy'])/2                  # 변수 조합
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')  # 조건문 활용

# 6. 빈도 확인하기
count_test = mpg['test'].value_counts()  # 빈도표 만들기
count_test.plot.bar(rot = 0)             # 빈도 막대 그래프 만들기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB
# <Axes: >
